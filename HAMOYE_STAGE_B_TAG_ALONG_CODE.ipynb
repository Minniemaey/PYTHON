# %% [markdown]
# NAME: ODEDEYI AMINAT YEWANDE

# %% [markdown]
# Machine Learning: Regression - Predicting Energy Efficiency of Buildings

# %%
# Importing modules and libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
#Importing and reading dataset to dataframe
data = pd.read_csv("/content/energydata_complete.csv")
data.head(7)
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
# 5  2016-01-11 17:50:00          50      40  19.89  46.026667  19.2  44.500000
# 6  2016-01-11 18:00:00          60      50  19.89  45.766667  19.2  44.500000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# ...

# %%
data.tail(5)
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3    T4  ...    T9     RH_9  \
# 19730  25.890000  42.025714  27.200000  41.163333  24.7  ...  23.2  46.7900
# 19731  25.754000  42.080000  27.133333  41.223333  24.7  ...  23.2  46.7900
# 19732  25.628571  42.768571  27.050000  41.690000  24.7  ...  23.2  46.7900
# 19733  25.414000  43.036000  26.890000  41.290000  24.7  ...  23.2  46.8175
# 19734  25.264286  42.971429  26.823333  41.156667  24.7  ...  23.2  46.8450
#
#            T_out  Press_mm_hg     RH_out  Windspeed  Visibility  Tdewpoint  \
# ...

# %%
#checking dataframe info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
#checks for dataset description
data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
#checks for dimension(rows and columns)
data.shape
# Out:
# (19735, 29)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#checking for missing or null values
data.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
data.nunique()
# Out:
# date           19735
# Appliances        92
# lights             8
# T1               722
# RH_1            2547
# T2              1650
# RH_2            3376
# T3              1426
# RH_3            2618
# T4              1390
# RH_4            2987
# T5              2263
# RH_5            7571
# T6              4446
# RH_6            9709
# T7              1955
# RH_7            5891
# T8              2228
# RH_8            6649
# T9               924
# RH_9            3388
# T_out           1730
# Press_mm_hg     2189
# RH_out           566
# Windspeed        189
# Visibility       413
# Tdewpoint       1409
# rv1            19735
# rv2            19735
# dtype: int64

# %%
print(data.dtypes)
print(data.size)
# Out:
# date            object
# Appliances       int64
# lights           int64
# T1             float64
# RH_1           float64
# T2             float64
# RH_2           float64
# T3             float64
# RH_3           float64
# T4             float64
# RH_4           float64
# T5             float64
# RH_5           float64
# T6             float64
# RH_6           float64
# T7             float64
# RH_7           float64
# T8             float64
# RH_8           float64
# T9             float64
# RH_9           float64
# T_out          float64
# Press_mm_hg    float64
# RH_out         float64
# Windspeed      float64
# Visibility     float64
# Tdewpoint      float64
# rv1            float64
# rv2            float64
# dtype: object
# 572315

# %%
#EDA
#visualization of regression plot
plt.figure(figsize=(8,5))
sns.regplot(x='T2', y='T6', data=data)
# Out:
# <Axes: xlabel='T2', ylabel='T6'>

# %%
data.corr()
# Out:
#              Appliances    lights        T1      RH_1        T2      RH_2  \
# Appliances     1.000000  0.197278  0.055447  0.086031  0.120073 -0.060465
# lights         0.197278  1.000000 -0.023528  0.106968 -0.005622  0.050985
# T1             0.055447 -0.023528  1.000000  0.164006  0.836834 -0.002509
# RH_1           0.086031  0.106968  0.164006  1.000000  0.269839  0.797535
# T2             0.120073 -0.005622  0.836834  0.269839  1.000000 -0.165610
# RH_2          -0.060465  0.050985 -0.002509  0.797535 -0.165610  1.000000
# T3             0.085060 -0.097393  0.892402  0.253230  0.735245  0.137319
# RH_3           0.036292  0.131161 -0.028550  0.844677  0.121497  0.678326
# T4             0.040281 -0.008859  0.877001  0.106180  0.762066 -0.047304
# RH_4           0.016965  0.114936  0.097861  0.880359  0.231563  0.721435
# T5             0.019760 -0.078745  0.885247  0.205797  0.720550  0.110409
# RH_5           0.006955  0.141233 -0.014782  0.303258  0.029595  0.250271
# ...

# %%
#Question 17

x = data.T2
#reshaping x to fit model, x then becomes
x = np.array(data.T2)
x_arr = x.reshape(-1, 1)
y_arr = data.T6
#data is split into training and test dataset
x_train, x_test, y_train, y_test = train_test_split(x_arr, y_arr, test_size = 0.3, train_size= 0.7, random_state = 42)
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#model prediction
pred_values = model.predict(x_test)

# %%
#Root Mean Squared Error to 3d.p
RMSE = np.sqrt(mean_squared_error(y_test,pred_values))
round(RMSE,3)
# Out:
# 3.63

# %%
#R2 value
r2 = r2_score(y_test,pred_values)
round(r2,2)
# Out:
# 0.64

# %%
#Question 18
#Dropping date and lights columns
data_df1 = data.drop(columns = ["date","lights"], axis = 1)
data_df1
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
#Normalizing with minmaxscaler
scaler = MinMaxScaler()
norm_data = pd.DataFrame(scaler.fit_transform(data_df1), columns = data_df1.columns)
norm_data.head()
x_feature = norm_data.drop(['Appliances'], axis = 1)
y_target = norm_data['Appliances']

# %%
#model splitting and fitting
model2 = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(x_feature, y_target, train_size = 0.7, test_size = 0.3, random_state = 42)
model2.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#model prediction
pred_values2 = model2.predict(x_test)

# %%
#Mean Absolute Error in 3dp = 0.050
MAE = mean_absolute_error(y_test, pred_values2)
round(MAE,3)
# Out:
# 0.05

# %%
#Residual Sum of Square
RSS = np.sum(np.square(y_test - pred_values2))
round(RSS,2)
# Out:
# 45.35

# %%
#Question 19
#Root Mean Squared Error in 3dp = 0.088
RMSE = np.sqrt(mean_squared_error(y_test,pred_values2))
round(RMSE,3)
# Out:
# 0.088

# %%
#Coefficient of determination (R_squared)
R2 = r2_score(y_test,pred_values2)
round(R2,2)
# Out:
# 0.15

# %%
def feat_weights(model, feat, col_name):
    weights = pd.Series(model.coef_,feat.columns).sort_values()
    feature_weights = pd.DataFrame(weights).reset_index()
    feature_weights.columns = ["Model Features",col_name]
    feature_weights[col_name].round(3)
    return feature_weights

# %%
feature_weights = feat_weights(model2, x_train, 'Weights')
feature_weights
# Out:
#    Model Features   Weights
# 0            RH_2 -0.456698
# 1           T_out -0.321860
# 2              T2 -0.236178
# 3              T9 -0.189941
# 4            RH_8 -0.157595
# 5          RH_out -0.077671
# 6            RH_7 -0.044614
# 7            RH_9 -0.039800
# 8              T5 -0.015657
# 9              T1 -0.003281
# 10            rv1  0.000770
# 11            rv2  0.000770
# 12    Press_mm_hg  0.006839
# 13             T7  0.010319
# 14     Visibility  0.012307
# 15           RH_5  0.016006
# 16           RH_4  0.026386
# 17             T4  0.028981
# 18      Windspeed  0.029183
# 19           RH_6  0.038049
# 20           RH_3  0.096048
# 21             T8  0.101995
# 22      Tdewpoint  0.117758
# 23             T6  0.236425
# 24             T3  0.290627
# 25           RH_1  0.553547

# %%
#lowest weights
feature_weights.nsmallest(1, "Weights")
# Out:
#   Model Features   Weights
# 0           RH_2 -0.456698

# %%
#largest weights
feature_weights.nlargest(1, "Weights")
# Out:
#    Model Features   Weights
# 25           RH_1  0.553547

# %%
#Question 23
#Ridge Regression Model
regmodel = Ridge(alpha = 0.4)

#fitting the ridge model and model prediction
regmodel.fit(x_train, y_train)
reg_predvalues = regmodel.predict(x_test)

# %%
#Root Mean Squared Error (RMSE)
rRMSE = np.sqrt(mean_squared_error(y_test, reg_predvalues))
round(rRMSE,2)

#The Root Mean Squared Error (RMSE) on Ridge Regression model and Linear model are almost equal
#Thus, there is no changes in the RMSE
# Out:
# 0.09

# %%
#Question 24
#Lasso Regression Model
lasmodel = Lasso(alpha = 0.001)

#fitting and predicting the model
lasmodel.fit(x_train, y_train)
las_predvalues = lasmodel.predict(x_test)

las_weight = feat_weights(lasmodel, x_train,"Lasso Weights")
las_weight
# Out:
#    Model Features  Lasso Weights
# 0          RH_out      -0.049557
# 1            RH_8      -0.000110
# 2              T1       0.000000
# 3       Tdewpoint       0.000000
# 4      Visibility       0.000000
# 5     Press_mm_hg      -0.000000
# 6           T_out       0.000000
# 7            RH_9      -0.000000
# 8              T9      -0.000000
# 9              T8       0.000000
# 10           RH_7      -0.000000
# 11            rv1      -0.000000
# 12             T7      -0.000000
# 13             T6       0.000000
# 14           RH_5       0.000000
# 15             T5      -0.000000
# 16           RH_4       0.000000
# 17             T4      -0.000000
# 18           RH_3       0.000000
# 19             T3       0.000000
# 20           RH_2      -0.000000
# 21             T2       0.000000
# 22           RH_6      -0.000000
# 23            rv2      -0.000000
# 24      Windspeed       0.002912
# 25           RH_1       0.017880

# %%
#Question 24
non_zero = las_weight[las_weight["Lasso Weights"] != 0]
len(non_zero)
# Out:
# 4

# %%
#Question 25
#new RMSE with lasso regression
las_predvalues = lasmodel.predict(x_test)
lRMSE = np.sqrt(mean_squared_error(y_test, las_predvalues))
round(lRMSE, 3)
# Out:
# 0.094
